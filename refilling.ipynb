# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "C:/Users/louis/OneDrive/Documents/University of Manchester/Physics/Year 4/MPhys/data/refill/"

# %%
spark_line_refill = np.genfromtxt(path+'spark_line_refill.csv', delimiter=',')
optical_line_refill = np.genfromtxt(path+'optical_line_refill.csv', delimiter=',')

# %%
plt.title("Spark Line Refilling")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(spark_line_refill[:,0], spark_line_refill[:,1], "k.", label='Spark Line')

# %%
plt.title("Optical Line Refilling")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(optical_line_refill[:,0], optical_line_refill[:,1], "k.", label='optical Line')

# %%
refill_18_02_25 = np.genfromtxt(path+'refill_18_02_25.csv', delimiter=',', skip_header=1)

# %%
plt.title("Spark Line Refilling 18/02/25")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(refill_18_02_25[:,2], refill_18_02_25[:,3], "k.", label='Spark Line')

# %%
plt.title("Optical Line Refilling 18/02/25")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(refill_18_02_25[:,0], refill_18_02_25[:,1], "k.", label='Optical Line')

# %%
refill_20_03_25 = np.genfromtxt(path+'refill_20_03_25.csv', delimiter=',', skip_header=1)
refill_20_03_25_2 = np.genfromtxt(path+'refill_20_03_25_2.csv', delimiter=',', skip_header=1)
optical_20_03_25 = np.genfromtxt(path+'optical_20_03_25.csv', delimiter=',', skip_header=1) 
refill_25_02_25 = np.genfromtxt(path+'refill_25_02_25.csv', delimiter=',', skip_header=1)
refill_27_03_25 = np.genfromtxt(path+'refill_27_03_25.csv', delimiter=',', skip_header=1)
refill_01_04_25 = np.genfromtxt(path+'refill_01_04_25.csv', delimiter=',', skip_header=1)

# %%
plt.title("Spark Line Refilling")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(spark_line_refill[:,0], spark_line_refill[:,1], "g.", label='13/02/25')
plt.plot(refill_18_02_25[:,2], refill_18_02_25[:,3], "r.", label='18/02/25')
plt.plot(refill_25_02_25[:,3], refill_25_02_25[:,1], "c.", label='25/02/25 CG1')
plt.plot(refill_25_02_25[:,3], refill_25_02_25[:,2], "m.", label='25/02/25 CG2')
plt.plot(refill_20_03_25[:,0], refill_20_03_25[:,1], "k.", label='20/03/25')
plt.plot(refill_20_03_25_2[:,0], refill_20_03_25_2[:,1], "b.", label='20/03/25 Attempt 2')
plt.plot(refill_27_03_25[:,0], refill_27_03_25[:,1], "y.", label='27/03/25')
plt.legend()
plt.show()

# %%
plt.title("Optical Line Refilling")
plt.ylabel("Pressure (mBar)")
plt.xlabel("Time (s)")
#plt.yscale("log")
#plt.xscale("log")
plt.plot(optical_line_refill[:,0], optical_line_refill[:,1], "g.", label='13/02/25 IG')
plt.plot(refill_18_02_25[:,0], refill_18_02_25[:,1], "r.", label='18/02/25 IG')
plt.plot(refill_25_02_25[:,3][0:24], refill_25_02_25[:,0][0:24], "c.", label='25/02/25 IG')
plt.plot(optical_20_03_25[:,0], optical_20_03_25[:,1], "k.", label='20/03/25 IG')
plt.plot(optical_20_03_25[:,0], optical_20_03_25[:,2], "b.", label='20/03/25 CG')
plt.plot(refill_01_04_25[:,0], refill_01_04_25[:,1], "m.", label='01/04/25 IG')
plt.plot(refill_01_04_25[:,0], refill_01_04_25[:,2], "y.", label='01/04/25 CG')
plt.legend()
plt.show()
